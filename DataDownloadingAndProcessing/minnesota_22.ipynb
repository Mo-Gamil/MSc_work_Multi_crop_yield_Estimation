# %%
from helper_functions import *

# %%
variable_sets = [

{'a': r'MINNESOTA/Minnesota_32615/2022/2022_combined.shp', 'b': 'EPSG:32615', 'c': '2022-01-01', 'd': '2022-12-30', 'e': '2022-07-01', 'f': '2022-08-30'}
]

# %%
authenticate_gee()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=Ng-Mi5q1VjLEjtYeu1Jv0JE5ZNTqYoP9ep7ijyZJbKg&tc=6So75Jj5pwwAqFV-159L0Z75vVEHsTvvoyBuLBPAH4U&cc=9zBAwwqZBECA1g0bTZnIQc_B1ayUUoj5F2IIy5ccttQ>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=Ng-Mi5q1VjLEjtYeu1Jv0JE5ZNTqYoP9ep7ijyZJbKg&tc=6So75Jj5pwwAqFV-159L0Z75vVEHsTvvoyBuLBPAH4U&cc=9zBAwwqZBECA1g0bTZnIQc_B1ayUUoj5F2IIy5ccttQ</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Successfully saved authorization token.

# %%
for i, vars in enumerate(variable_sets):
    center_points_shapefile_path= vars['a'] 
    crs = vars['b'] 
    CDL_start_date = vars['c'] 
    CDL_end_date = vars['d'] 
    sen2_start_date = vars['e'] 
    sen2_end_date = vars['f']
    bands = ['B2', 'B3', 'B4','B5', 'B6','B7','B8',"B8A"]
    cloud_cover_max = 8
    buffer_dist = 1120 
    points = read_random_points(center_points_shapefile_path)
    

    # download cDL patches
    output_CDL_path= os.path.dirname(center_points_shapefile_path)
    output_CDL_path = os.path.join(output_CDL_path, 'CDL_images')
    os.makedirs(output_CDL_path, exist_ok=True)


    download_CDL_patches_from_GEE_to_local_desk(points,CDL_start_date,CDL_end_date,1120,output_CDL_path,crs)

    # download sent2 patches

    output_sen2_path= os.path.dirname(center_points_shapefile_path)
    output_sen2_path = os.path.join(output_sen2_path, 'sent2_images')
    os.makedirs(output_sen2_path, exist_ok=True)
    download_sent2_image_patches_from_GEE_to_local_desk(points,sen2_start_date,sen2_end_date,cloud_cover_max,1120,output_sen2_path,bands,crs)




    # clip sent2 patches
    #change size of sent2
    folder_path = output_sen2_path


    sent2_images_clipped_path = os.path.dirname(center_points_shapefile_path)
    sent2_images_clipped_path = os.path.join(sent2_images_clipped_path, 'sent2_images_clipped')
    os.makedirs(sent2_images_clipped_path, exist_ok=True)
    change_patches_size_in_folder(folder_path,sent2_images_clipped_path,224)

    #change size of cdl
    folder_path = output_CDL_path

    CDL_images_clipped_path = os.path.dirname(center_points_shapefile_path)
    CDL_images_clipped_path = os.path.join(CDL_images_clipped_path, 'CDL_images_clipped')

    os.makedirs(CDL_images_clipped_path, exist_ok=True)
    change_patches_size_in_folder(folder_path,CDL_images_clipped_path,224)


    # Normalize sent2 patches

    sent2_images_clipped_path = os.path.dirname(center_points_shapefile_path)
    sent2_images_clipped_path = os.path.join(sent2_images_clipped_path, 'sent2_images_clipped')
    os.makedirs(sent2_images_clipped_path, exist_ok=True)



    input_folder_before_normalization= sent2_images_clipped_path
    output_folder_after_normalization = os.path.dirname(center_points_shapefile_path)
    output_folder_after_normalization = os.path.join(output_folder_after_normalization, 'sent2_images_clipped_normalized')
    os.makedirs(output_folder_after_normalization, exist_ok=True)
    normalize_sent2_pixel_values(input_folder_before_normalization, output_folder_after_normalization)


    # change_background pixel values of cdl
    input_dir = CDL_images_clipped_path
    center_points_shapefile_path = center_points_shapefile_path
    CDL_images_final = os.path.dirname(center_points_shapefile_path)
    CDL_images_final = os.path.join(CDL_images_final, 'CDL_images_final')
    os.makedirs(CDL_images_clipped_path, exist_ok=True)
    setBackgroundToZero_of_CDL(input_dir, CDL_images_final)



    # Remap the pixel values of CDL
    # Specify the input and output folders
    input_folder = CDL_images_final
    CDL_images_final_mapped = os.path.dirname(center_points_shapefile_path)
    CDL_images_final_mapped = os.path.join(CDL_images_final_mapped, 'CDL_images_final_mapped')
    os.makedirs(CDL_images_final_mapped, exist_ok=True)
    

    # Process all images
    map_cdl_images_in_folder(input_folder, CDL_images_final_mapped)


    

    # calculate the crop yeild

    CDL_images_final_mapped = CDL_images_final_mapped
    points_shapefile_path = center_points_shapefile_path
    crop_yield = calculate_crop_yield(CDL_images_final_mapped,points_shapefile_path)


    # save the crop yield csv file


    # Extract directory and construct new CSV file path
    directory = os.path.dirname(center_points_shapefile_path)
    year = os.path.basename(directory)
    base_name = os.path.basename(os.path.dirname(directory))
    csv_file_name = f"{base_name}_{year}_cropYield.csv"
    csv_file_path = os.path.join(directory, csv_file_name)

    # Write list to CSV file
    with open(csv_file_path, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['Index', 'patch_Name', 'soy_y_bu_per_m2', 'corn_y_bu_per_m2', 'soy_y_bu_per_patch', 'corn_y_bu_per_patch'])  # Write header
        for row in crop_yield:
            writer.writerow(row)  # Write each tuple as a row

        # print(f"List saved to {csv_file_path}")
# Out:
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/79632946e6afa17428d94fe82be5a791-791bd548f918c30d5aff9345660e630b:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/MINNESOTA/Minnesota_32615/2022/CDL_images/1_MN_FREEBORN_2022.0.tif
# Downloaded 1_MN_FREEBORN_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/96425aa869c116167db722ddf619b4df-ffcafa7d73929a2141f7065f9f7613e4:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/MINNESOTA/Minnesota_32615/2022/CDL_images/2_MN_NOBLES_2022.0.tif
# Downloaded 2_MN_NOBLES_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/ba7720b7737b25096597308bebc5a251-2f1c5da64007bb9af531af635b21c0c0:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/MINNESOTA/Minnesota_32615/2022/CDL_images/3_MN_FARIBAULT_2022.0.tif
# Downloaded 3_MN_FARIBAULT_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/3b413746878bef2b8feae29d2b896730-b8a9a02b9da39e6c7b8d091b8f416561:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/MINNESOTA/Minnesota_32615/2022/CDL_images/4_MN_MOWER_2022.0.tif
# Downloaded 4_MN_MOWER_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/3cd669cc78c490151fb7720c024e760d-49bc382dfe7f8c83c3a47ec5dc664903:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/MINNESOTA/Minnesota_32615/2022/CDL_images/5_MN_NOBLES_2022.0.tif
# Downloaded 5_MN_NOBLES_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b00e8da526e687da6c1b0188309d7410-ad733bc44dee6006e87e42b8691684bf:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/MINNESOTA/Minnesota_32615/2022/CDL_images/6_MN_ROCK_2022.0.tif
# Downloaded 6_MN_ROCK_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/7c3074401148c3999cb846b5ceae14ac-5b015f88f2ff93143e5c7107c491b1a8:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/MINNESOTA/Minnesota_32615/2022/CDL_images/7_MN_MARTIN_2022.0.tif
# Downloaded 7_MN_MARTIN_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/1b97cda17c8ca1668d89277ae542ac16-88c3c3e8e0022760e351632345c84680:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/MINNESOTA/Minnesota_32615/2022/CDL_images