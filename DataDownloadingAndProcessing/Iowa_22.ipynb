# %%
from helper_functions import *

# %%
variable_sets = [

{'a': r'IOWA/Iowa_32615/2022/2022_combined.shp', 'b': 'EPSG:32615', 'c': '2022-01-01', 'd': '2022-12-30', 'e': '2022-07-01', 'f': '2022-08-30'}
]

# %%
authenticate_gee()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=meTIQ_jC20r_NZk5p7F0b_V26EQ1tOhN7p2pehS2veU&tc=eT2G2hIzMK_EgwGZNLat99chDY6S2d-2rtQhYf6vO3M&cc=AuoeKTc0MPrjJ-VnL2Q8QLAEBxI5p3CXpEB1BzUX6pw>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=meTIQ_jC20r_NZk5p7F0b_V26EQ1tOhN7p2pehS2veU&tc=eT2G2hIzMK_EgwGZNLat99chDY6S2d-2rtQhYf6vO3M&cc=AuoeKTc0MPrjJ-VnL2Q8QLAEBxI5p3CXpEB1BzUX6pw</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Successfully saved authorization token.

# %%
for i, vars in enumerate(variable_sets):
    center_points_shapefile_path= vars['a'] 
    crs = vars['b'] 
    CDL_start_date = vars['c'] 
    CDL_end_date = vars['d'] 
    sen2_start_date = vars['e'] 
    sen2_end_date = vars['f']
    bands = ['B2', 'B3', 'B4','B5', 'B6','B7','B8',"B8A"]
    cloud_cover_max = 8
    buffer_dist = 1120 
    points = read_random_points(center_points_shapefile_path)
    

    # download cDL patches
    output_CDL_path= os.path.dirname(center_points_shapefile_path)
    output_CDL_path = os.path.join(output_CDL_path, 'CDL_images')
    os.makedirs(output_CDL_path, exist_ok=True)


    download_CDL_patches_from_GEE_to_local_desk(points,CDL_start_date,CDL_end_date,1120,output_CDL_path,crs)

    # download sent2 patches

    output_sen2_path= os.path.dirname(center_points_shapefile_path)
    output_sen2_path = os.path.join(output_sen2_path, 'sent2_images')
    os.makedirs(output_sen2_path, exist_ok=True)
    download_sent2_image_patches_from_GEE_to_local_desk(points,sen2_start_date,sen2_end_date,cloud_cover_max,1120,output_sen2_path,bands,crs)




    # clip sent2 patches
    #change size of sent2
    folder_path = output_sen2_path


    sent2_images_clipped_path = os.path.dirname(center_points_shapefile_path)
    sent2_images_clipped_path = os.path.join(sent2_images_clipped_path, 'sent2_images_clipped')
    os.makedirs(sent2_images_clipped_path, exist_ok=True)
    change_patches_size_in_folder(folder_path,sent2_images_clipped_path,224)

    #change size of cdl
    folder_path = output_CDL_path

    CDL_images_clipped_path = os.path.dirname(center_points_shapefile_path)
    CDL_images_clipped_path = os.path.join(CDL_images_clipped_path, 'CDL_images_clipped')

    os.makedirs(CDL_images_clipped_path, exist_ok=True)
    change_patches_size_in_folder(folder_path,CDL_images_clipped_path,224)


    # Normalize sent2 patches

    sent2_images_clipped_path = os.path.dirname(center_points_shapefile_path)
    sent2_images_clipped_path = os.path.join(sent2_images_clipped_path, 'sent2_images_clipped')
    os.makedirs(sent2_images_clipped_path, exist_ok=True)



    input_folder_before_normalization= sent2_images_clipped_path
    output_folder_after_normalization = os.path.dirname(center_points_shapefile_path)
    output_folder_after_normalization = os.path.join(output_folder_after_normalization, 'sent2_images_clipped_normalized')
    os.makedirs(output_folder_after_normalization, exist_ok=True)
    normalize_sent2_pixel_values(input_folder_before_normalization, output_folder_after_normalization)


    # change_background pixel values of cdl
    input_dir = CDL_images_clipped_path
    center_points_shapefile_path = center_points_shapefile_path
    CDL_images_final = os.path.dirname(center_points_shapefile_path)
    CDL_images_final = os.path.join(CDL_images_final, 'CDL_images_final')
    os.makedirs(CDL_images_clipped_path, exist_ok=True)
    setBackgroundToZero_of_CDL(input_dir, CDL_images_final)



    # Remap the pixel values of CDL
    # Specify the input and output folders
    input_folder = CDL_images_final
    CDL_images_final_mapped = os.path.dirname(center_points_shapefile_path)
    CDL_images_final_mapped = os.path.join(CDL_images_final_mapped, 'CDL_images_final_mapped')
    os.makedirs(CDL_images_final_mapped, exist_ok=True)
    

    # Process all images
    map_cdl_images_in_folder(input_folder, CDL_images_final_mapped)


    

    # calculate the crop yeild

    CDL_images_final_mapped = CDL_images_final_mapped
    points_shapefile_path = center_points_shapefile_path
    crop_yield = calculate_crop_yield(CDL_images_final_mapped,points_shapefile_path)


    # save the crop yield csv file


    # Extract directory and construct new CSV file path
    directory = os.path.dirname(center_points_shapefile_path)
    year = os.path.basename(directory)
    base_name = os.path.basename(os.path.dirname(directory))
    csv_file_name = f"{base_name}_{year}_cropYield.csv"
    csv_file_path = os.path.join(directory, csv_file_name)

    # Write list to CSV file
    with open(csv_file_path, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['Index', 'patch_Name', 'soy_y_bu_per_m2', 'corn_y_bu_per_m2', 'soy_y_bu_per_patch', 'corn_y_bu_per_patch'])  # Write header
        for row in crop_yield:
            writer.writerow(row)  # Write each tuple as a row

        # print(f"List saved to {csv_file_path}")
# Out:
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/2472c9204fad42269ad1670cdfe2e3de-0e5574d1f9ca0f807630815fd7ef4f2d:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/IOWA/Iowa_32615/2022/CDL_images/1_IA_LEE_2022.0.tif
# Downloaded 1_IA_LEE_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/8b8938b00f4b81f99c641eee19c79748-d5e02efd322adf3c176c1c3ce7717c19:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/IOWA/Iowa_32615/2022/CDL_images/2_IA_LEE_2022.0.tif
# Downloaded 2_IA_LEE_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/44ef8fe01e1f5c8ecf19a4db8e47f13e-08738d9965d39a9f36b2ae4833fac06e:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/IOWA/Iowa_32615/2022/CDL_images/3_IA_LEE_2022.0.tif
# Downloaded 3_IA_LEE_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/dd78869e4dc6d8e68ce33cc64a0c8e11-5225d97385389bf9b1640a073756f9a5:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/IOWA/Iowa_32615/2022/CDL_images/4_IA_LEE_2022.0.tif
# Downloaded 4_IA_LEE_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/7a29c470839939f7bf8efe5376daa466-ef0ff5f5eef27f432994d5712571767a:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/IOWA/Iowa_32615/2022/CDL_images/5_IA_LEE_2022.0.tif
# Downloaded 5_IA_LEE_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/bc1d1f33448410091a7915150a1bbbd6-0c14af35820ea92e5ad1ab34837347d3:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/IOWA/Iowa_32615/2022/CDL_images/6_IA_LEE_2022.0.tif
# Downloaded 6_IA_LEE_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/21e2407b5be10d7a247e3667d95e8580-b37ccc135d8dc4f9588b5d6e6bd2a2cb:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/IOWA/Iowa_32615/2022/CDL_images/7_IA_TAYLOR_2022.0.tif
# Downloaded 7_IA_TAYLOR_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/26310b5a75bc1d73ed07e6473d6c397a-937197c93293d9241e1ede274d90a583:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/IOWA/Iowa_32615/2022/CDL_images/8_IA_LEE_2022.0.tif
# Downloaded 8_IA_LEE_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/f94651ef3e29c4bd53c53a7a963b634c-bc71ab1df77a4a773ee84e6953c0cdf3:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/IOWA/Iowa_32615/2022/CDL_images/9_IA_DECATUR_2022.0.tif
# Downloaded 9_IA_DECATUR_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/2e4a35fd530f4bd8abe7dadb153c59f0-48d4061b2138f8e2c35d54e3f397932b:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/IOWA/Iowa_32615/2022/CDL_images/10_IA_RINGGOLD_2022.0.tif
# Downloaded 10_IA_RINGGOLD_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/d82767e68e5f87ce9373fab2eaf0d590-fb5763a642252639f339270bc320f222:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/IOWA/Iowa_32615/2022/CDL_images/11_IA_PAGE_2022.0.tif
# Downloaded 11_IA_PAGE_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/5db719939d7a22009f7ab95d008c3412-6ca3844e07adee85e938f8b974995c79:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/IOWA/Iowa_32615/2022/CDL_images