# %%
from helper_functions import *

# %%
variable_sets = [

{'a': r'ILLINOIS/Illinois_32616/2022/2022_combined.shp', 'b': 'EPSG:32616', 'c': '2022-01-01', 'd': '2022-12-30', 'e': '2022-07-01', 'f': '2022-08-30'}
]

# %%
authenticate_gee()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=fU3ON0wwbZpp6sT8nFmKg3M1_b5SijYbAoNd7j6E_Xc&tc=StXe8oODk6fcGNRNt1KwCVw4d5P_2kAUns68e5-DTUE&cc=p87ZqYrc1w1jwXh-hEHt8LDEdr1zHzILmh1BVFmIhkc>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=fU3ON0wwbZpp6sT8nFmKg3M1_b5SijYbAoNd7j6E_Xc&tc=StXe8oODk6fcGNRNt1KwCVw4d5P_2kAUns68e5-DTUE&cc=p87ZqYrc1w1jwXh-hEHt8LDEdr1zHzILmh1BVFmIhkc</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Successfully saved authorization token.

# %%
for i, vars in enumerate(variable_sets):
    center_points_shapefile_path= vars['a'] 
    crs = vars['b'] 
    CDL_start_date = vars['c'] 
    CDL_end_date = vars['d'] 
    sen2_start_date = vars['e'] 
    sen2_end_date = vars['f']
    bands = ['B2', 'B3', 'B4','B5', 'B6','B7','B8',"B8A"]
    cloud_cover_max = 8
    buffer_dist = 1120 
    points = read_random_points(center_points_shapefile_path)
    # points=points[0:10]

    # download cDL patches
    output_CDL_path= os.path.dirname(center_points_shapefile_path)
    output_CDL_path = os.path.join(output_CDL_path, 'CDL_images')
    os.makedirs(output_CDL_path, exist_ok=True)


    download_CDL_patches_from_GEE_to_local_desk(points,CDL_start_date,CDL_end_date,1120,output_CDL_path,crs)

    # download sent2 patches

    output_sen2_path= os.path.dirname(center_points_shapefile_path)
    output_sen2_path = os.path.join(output_sen2_path, 'sent2_images')
    os.makedirs(output_sen2_path, exist_ok=True)
    download_sent2_image_patches_from_GEE_to_local_desk(points,sen2_start_date,sen2_end_date,cloud_cover_max,1120,output_sen2_path,bands,crs)




    # clip sent2 patches
    #change size of sent2
    folder_path = output_sen2_path


    sent2_images_clipped_path = os.path.dirname(center_points_shapefile_path)
    sent2_images_clipped_path = os.path.join(sent2_images_clipped_path, 'sent2_images_clipped')
    os.makedirs(sent2_images_clipped_path, exist_ok=True)
    change_patches_size_in_folder(folder_path,sent2_images_clipped_path,224)

    #change size of cdl
    folder_path = output_CDL_path

    CDL_images_clipped_path = os.path.dirname(center_points_shapefile_path)
    CDL_images_clipped_path = os.path.join(CDL_images_clipped_path, 'CDL_images_clipped')

    os.makedirs(CDL_images_clipped_path, exist_ok=True)
    change_patches_size_in_folder(folder_path,CDL_images_clipped_path,224)


    # Normalize sent2 patches

    sent2_images_clipped_path = os.path.dirname(center_points_shapefile_path)
    sent2_images_clipped_path = os.path.join(sent2_images_clipped_path, 'sent2_images_clipped')
    os.makedirs(sent2_images_clipped_path, exist_ok=True)



    input_folder_before_normalization= sent2_images_clipped_path
    output_folder_after_normalization = os.path.dirname(center_points_shapefile_path)
    output_folder_after_normalization = os.path.join(output_folder_after_normalization, 'sent2_images_clipped_normalized')
    os.makedirs(output_folder_after_normalization, exist_ok=True)
    normalize_sent2_pixel_values(input_folder_before_normalization, output_folder_after_normalization)


    # change_background pixel values of cdl
    input_dir = CDL_images_clipped_path
    center_points_shapefile_path = center_points_shapefile_path
    CDL_images_final = os.path.dirname(center_points_shapefile_path)
    CDL_images_final = os.path.join(CDL_images_final, 'CDL_images_final')
    os.makedirs(CDL_images_clipped_path, exist_ok=True)
    setBackgroundToZero_of_CDL(input_dir, CDL_images_final)



    # Remap the pixel values of CDL
    # Specify the input and output folders
    input_folder = CDL_images_final
    CDL_images_final_mapped = os.path.dirname(center_points_shapefile_path)
    CDL_images_final_mapped = os.path.join(CDL_images_final_mapped, 'CDL_images_final_mapped')
    os.makedirs(CDL_images_final_mapped, exist_ok=True)
    

    # Process all images
    map_cdl_images_in_folder(input_folder, CDL_images_final_mapped)


    

    # calculate the crop yeild

    CDL_images_final_mapped = CDL_images_final_mapped
    points_shapefile_path = center_points_shapefile_path
    crop_yield = calculate_crop_yield(CDL_images_final_mapped,points_shapefile_path)


    # save the crop yield csv file


    # Extract directory and construct new CSV file path
    directory = os.path.dirname(center_points_shapefile_path)
    year = os.path.basename(directory)
    base_name = os.path.basename(os.path.dirname(directory))
    csv_file_name = f"{base_name}_{year}_cropYield.csv"
    csv_file_path = os.path.join(directory, csv_file_name)

    # Write list to CSV file
    with open(csv_file_path, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['Index', 'patch_Name', 'soy_y_bu_per_m2', 'corn_y_bu_per_m2', 'soy_y_bu_per_patch', 'corn_y_bu_per_patch'])  # Write header
        for row in crop_yield:
            writer.writerow(row)  # Write each tuple as a row

        # print(f"List saved to {csv_file_path}")
# Out:
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/36801ad575b838a2898a34074fbf02d4-b65bd37408b45df411d0ed0d61fe611b:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/ILLINOIS/Illinois_32616/2022/CDL_images/1_IL_ALEXANDER_2022.0.tif
# Downloaded 1_IL_ALEXANDER_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/e4acb15b262c3fee50aa5c6c4c119c82-5e925098d8720f7905f3290a758d1019:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/ILLINOIS/Illinois_32616/2022/CDL_images/2_IL_ALEXANDER_2022.0.tif
# Downloaded 2_IL_ALEXANDER_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/ad7adca1b0231de2a8071ad750c4e250-018f60333a3f74b592bccf5b489f69fc:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/ILLINOIS/Illinois_32616/2022/CDL_images/3_IL_ALEXANDER_2022.0.tif
# Downloaded 3_IL_ALEXANDER_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/85ac5d3262a26a404c7558e61582676a-19c1f5b3a33b5b3a5ba96bcc820c7f8a:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/ILLINOIS/Illinois_32616/2022/CDL_images/4_IL_ALEXANDER_2022.0.tif
# Downloaded 4_IL_ALEXANDER_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/7f07ba12f716435e2a359c0cd5dd9ce7-accbdb9d60d5f69e4f3598a04d55313c:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/ILLINOIS/Illinois_32616/2022/CDL_images/5_IL_MASSAC_2022.0.tif
# Downloaded 5_IL_MASSAC_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/e9f318e70893a40c24b49bc548a7c7dc-a86d643584fab041228559da419e2094:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/ILLINOIS/Illinois_32616/2022/CDL_images/6_IL_ALEXANDER_2022.0.tif
# Downloaded 6_IL_ALEXANDER_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/1ee0c79c80925cba8fcb77a9644967c2-1afa2dbb396b8246e79f254a666d46f7:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/ILLINOIS/Illinois_32616/2022/CDL_images/7_IL_ALEXANDER_2022.0.tif
# Downloaded 7_IL_ALEXANDER_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/e5a28c81cf5be1b11277ffaf27beb209-90382f3a12fbc0309a2674b6d591dc23:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/ILLINOIS/Illinois_32616/2022/CDL_images/8_IL_PULASKI_2022.0.tif
# Downloaded 8_IL_PULASKI_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails