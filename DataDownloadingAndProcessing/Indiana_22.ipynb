# %%
from helper_functions import *

# %%
variable_sets = [

{'a': r'INDIANA/Indiana_32615/2022/2022_combined.shp', 'b': 'EPSG:32615', 'c': '2022-01-01', 'd': '2022-12-30', 'e': '2022-07-01', 'f': '2022-08-30'}
]

# %%
authenticate_gee()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=8R-Rrz3W-gRlF-I8WIsfxwdDYoURe8KHXGn9W5xAuS8&tc=ufkLbKnCuExGwjuMkVgjYFxZNtH7PK_HcRfdAbEL1wY&cc=X0-f2blGrGcAr8A-Tleuk0AZQV04GMrkrneZasVPI00>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=8R-Rrz3W-gRlF-I8WIsfxwdDYoURe8KHXGn9W5xAuS8&tc=ufkLbKnCuExGwjuMkVgjYFxZNtH7PK_HcRfdAbEL1wY&cc=X0-f2blGrGcAr8A-Tleuk0AZQV04GMrkrneZasVPI00</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Successfully saved authorization token.

# %%
for i, vars in enumerate(variable_sets):
    center_points_shapefile_path= vars['a'] 
    crs = vars['b'] 
    CDL_start_date = vars['c'] 
    CDL_end_date = vars['d'] 
    sen2_start_date = vars['e'] 
    sen2_end_date = vars['f']
    bands = ['B2', 'B3', 'B4','B5', 'B6','B7','B8',"B8A"]
    cloud_cover_max = 8
    buffer_dist = 1120 
    points = read_random_points(center_points_shapefile_path)
    

    # download cDL patches
    output_CDL_path= os.path.dirname(center_points_shapefile_path)
    output_CDL_path = os.path.join(output_CDL_path, 'CDL_images')
    os.makedirs(output_CDL_path, exist_ok=True)


    download_CDL_patches_from_GEE_to_local_desk(points,CDL_start_date,CDL_end_date,1120,output_CDL_path,crs)

    # download sent2 patches

    output_sen2_path= os.path.dirname(center_points_shapefile_path)
    output_sen2_path = os.path.join(output_sen2_path, 'sent2_images')
    os.makedirs(output_sen2_path, exist_ok=True)
    download_sent2_image_patches_from_GEE_to_local_desk(points,sen2_start_date,sen2_end_date,cloud_cover_max,1120,output_sen2_path,bands,crs)




    # clip sent2 patches
    #change size of sent2
    folder_path = output_sen2_path


    sent2_images_clipped_path = os.path.dirname(center_points_shapefile_path)
    sent2_images_clipped_path = os.path.join(sent2_images_clipped_path, 'sent2_images_clipped')
    os.makedirs(sent2_images_clipped_path, exist_ok=True)
    change_patches_size_in_folder(folder_path,sent2_images_clipped_path,224)

    #change size of cdl
    folder_path = output_CDL_path

    CDL_images_clipped_path = os.path.dirname(center_points_shapefile_path)
    CDL_images_clipped_path = os.path.join(CDL_images_clipped_path, 'CDL_images_clipped')

    os.makedirs(CDL_images_clipped_path, exist_ok=True)
    change_patches_size_in_folder(folder_path,CDL_images_clipped_path,224)


    # Normalize sent2 patches

    sent2_images_clipped_path = os.path.dirname(center_points_shapefile_path)
    sent2_images_clipped_path = os.path.join(sent2_images_clipped_path, 'sent2_images_clipped')
    os.makedirs(sent2_images_clipped_path, exist_ok=True)



    input_folder_before_normalization= sent2_images_clipped_path
    output_folder_after_normalization = os.path.dirname(center_points_shapefile_path)
    output_folder_after_normalization = os.path.join(output_folder_after_normalization, 'sent2_images_clipped_normalized')
    os.makedirs(output_folder_after_normalization, exist_ok=True)
    normalize_sent2_pixel_values(input_folder_before_normalization, output_folder_after_normalization)


    # change_background pixel values of cdl
    input_dir = CDL_images_clipped_path
    center_points_shapefile_path = center_points_shapefile_path
    CDL_images_final = os.path.dirname(center_points_shapefile_path)
    CDL_images_final = os.path.join(CDL_images_final, 'CDL_images_final')
    os.makedirs(CDL_images_clipped_path, exist_ok=True)
    setBackgroundToZero_of_CDL(input_dir, CDL_images_final)



    # Remap the pixel values of CDL
    # Specify the input and output folders
    input_folder = CDL_images_final
    CDL_images_final_mapped = os.path.dirname(center_points_shapefile_path)
    CDL_images_final_mapped = os.path.join(CDL_images_final_mapped, 'CDL_images_final_mapped')
    os.makedirs(CDL_images_final_mapped, exist_ok=True)
    

    # Process all images
    map_cdl_images_in_folder(input_folder, CDL_images_final_mapped)


    

    # calculate the crop yeild

    CDL_images_final_mapped = CDL_images_final_mapped
    points_shapefile_path = center_points_shapefile_path
    crop_yield = calculate_crop_yield(CDL_images_final_mapped,points_shapefile_path)


    # save the crop yield csv file


    # Extract directory and construct new CSV file path
    directory = os.path.dirname(center_points_shapefile_path)
    year = os.path.basename(directory)
    base_name = os.path.basename(os.path.dirname(directory))
    csv_file_name = f"{base_name}_{year}_cropYield.csv"
    csv_file_path = os.path.join(directory, csv_file_name)

    # Write list to CSV file
    with open(csv_file_path, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['Index', 'patch_Name', 'soy_y_bu_per_m2', 'corn_y_bu_per_m2', 'soy_y_bu_per_patch', 'corn_y_bu_per_patch'])  # Write header
        for row in crop_yield:
            writer.writerow(row)  # Write each tuple as a row

        # print(f"List saved to {csv_file_path}")
# Out:
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/9d21bbd5d5cbbbc3c3b8f415310e64ef-1d47783b7061d88eb653863e3e8efa93:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/2_IN_POSEY_2022.0.tif
# Downloaded 2_IN_POSEY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/8a6406ef787c0dc95646154c7e55fc1e-31f7acf5a26062bc691c5004153f8e23:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/5_IN_VANDERBURGH_2022.0.tif
# Downloaded 5_IN_VANDERBURGH_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/eac48f12da739f08ae63813946d1f8d8-90dd15cea0bb1100fa16dcb4e608e2be:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/6_IN_PERRY_2022.0.tif
# Downloaded 6_IN_PERRY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/7dcd03f689587111b9a0ff79d024ed61-6d5e8db3cf613c15c58b351dd224173c:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/8_IN_VANDERBURGH_2022.0.tif
# Downloaded 8_IN_VANDERBURGH_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/303ae69e23d594574162211af9cc4009-d6fc475dd13dc20870630aefd0a5a39d:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/10_IN_POSEY_2022.0.tif
# Downloaded 10_IN_POSEY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/832d0aa718b27b39d20a304df298ea8a-ef20c4db3288568367ab2d99fd09c460:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/11_IN_POSEY_2022.0.tif
# Downloaded 11_IN_POSEY_2022.0 image patch for corn and soybeans.
# No valid corn or soybean data found for 12_IN_PERRY_2022.0.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/eb45a3a4b66168472647504a88cb2d2d-c6160be7d5b8b7793ded10fa2f628d6f:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/15_IN_WARRICK_2022.0.tif
# Downloaded 15_IN_WARRICK_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/3a5e6ddb88166a2fa9347e13b5cee91a-6c1c3e8dae47f3bedfa0a800e67747ee:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/16_IN_VANDERBURGH_2022.0.tif
# Downloaded 16_IN_VANDERBURGH_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/2b4fe1f86e041ace98cabb43d660f698-876fd70a3e2dcffb531e22af2f90ab85:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/17_IN_PERRY_2022.0.tif
# Downloaded 17_IN_PERRY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/8994960c5393a290e6cb8166b1a6dbab-26021f55d6aa862bd4b53b7cab1ecb6a:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/18_IN_PERRY_2022.0.tif
# Downloaded 18_IN_PERRY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/ccec92129a88df32b7d3abe6053ae785-c79d7d2926fae20ece42d1bdd0d84c46:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/20_IN_PERRY_2022.0.tif
# Downloaded 20_IN_PERRY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/31a261772dc1e0c99045d00ae9827e9a-7566de8e8e0cc8c9e8970d4a64299b4e:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/21_IN_POSEY_2022.0.tif
# Downloaded 21_IN_POSEY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/ac83681efa437d2d26528d06aaf07c40-abae0ee01771804963b5120409f910ec:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/23_IN_POSEY_2022.0.tif
# Downloaded 23_IN_POSEY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/a4a7fa2c2e0b96e94abd840b35428336-97fdf1658f2bab63bd1d95955afce3c6:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/24_IN_POSEY_2022.0.tif
# Downloaded 24_IN_POSEY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/8c50087d78b40e4b651d8b0463b5017c-ce91f869670548848c7db529611fcf48:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/25_IN_WARRICK_2022.0.tif
# Downloaded 25_IN_WARRICK_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/261fe755b00d516c0bb543b0d63f7d75-5b502584392f3947d0e416c280c64c91:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/26_IN_VANDERBURGH_2022.0.tif
# Downloaded 26_IN_VANDERBURGH_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b5b870771c3b086184c93d531f04ed71-102052aafca27654972c81e270498a4f:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/27_IN_POSEY_2022.0.tif
# Downloaded 27_IN_POSEY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/48311df5d952e97d767df4126f3c2516-dc0850ab8864371d45fe800dffd55c74:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/28_IN_VANDERBURGH_2022.0.tif
# Downloaded 28_IN_VANDERBURGH_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/0bbbdfe20d489ba47fcb5c610eec2ea3-e39ba32c59c0498c2b71455a2bcd3392:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/29_IN_WARRICK_2022.0.tif
# Downloaded 29_IN_WARRICK_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/325adbf3bd98dcb2ebafd24f4c25567f-7b5e8379ffb99f706f18f8764dddad91:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/30_IN_WARRICK_2022.0.tif
# Downloaded 30_IN_WARRICK_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/aaa163acf71eab02cc6ebe61ec3acccf-600b930716e6b73cfb1e7ca6d9372af4:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/31_IN_WARRICK_2022.0.tif
# Downloaded 31_IN_WARRICK_2022.0 image patch for corn and soybeans.
# No valid corn or soybean data found for 33_IN_PERRY_2022.0.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/f3a6eb1b3b5817be6bc8182de7316021-f560173db6855e01067a7fbb78ff2e5c:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/34_IN_PERRY_2022.0.tif
# Downloaded 34_IN_PERRY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/50ab24012653a9f1f806e793323d8d40-fe02b6103241bed92e6129c24020cff9:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/35_IN_VANDERBURGH_2022.0.tif
# Downloaded 35_IN_VANDERBURGH_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/a4cb6b30fc1bbcf735129e9ec4e605a9-cfc80f82a107bf2f3e6f103ce0a6aace:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/37_IN_HARRISON_2022.0.tif
# Downloaded 37_IN_HARRISON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/3c3e957d43a71b7a1850e742a659d0ba-b7ed523d679f325577d054440c97aa1e:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/40_IN_POSEY_2022.0.tif
# Downloaded 40_IN_POSEY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/a1dd5d33226da993e4d3a182777f70f3-c4f601fe48909254f18a90515d4977ca:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/41_IN_POSEY_2022.0.tif
# Downloaded 41_IN_POSEY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/41d517799cca65e508bbff682d9782a3-990647b7d3216f00a7fbc73cd372f7ad:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/42_IN_PERRY_2022.0.tif
# Downloaded 42_IN_PERRY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b0df5ebba2c92fc8a7bc047a95bc954c-2989301f88f8111ecd0e6cf343b294cd:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/43_IN_VANDERBURGH_2022.0.tif
# Downloaded 43_IN_VANDERBURGH_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/201f88bee3e7ecc89805877c875e3aeb-6971d995c73850cf54645c63da77bf0a:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/44_IN_WARRICK_2022.0.tif
# Downloaded 44_IN_WARRICK_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/6338ac090c545c6851ff6168c57bb39d-5b1e40324e902e1fb755bf0aad7a697e:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/45_IN_PERRY_2022.0.tif
# Downloaded 45_IN_PERRY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/f806b0b85d9d81ca37d53bcf4953c2fa-9c2bf63b9cf7d081912878ddf7851b55:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/46_IN_PERRY_2022.0.tif
# Downloaded 46_IN_PERRY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/e44974e0ee07eaf5c4e0671bb767e70f-a8980f1305b6965e2bb1a14ae0777ba3:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/48_IN_HARRISON_2022.0.tif
# Downloaded 48_IN_HARRISON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/691c0428d15792fdff8734058139973f-ac9f2f142ecbbfa09235211507ae7464:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/49_IN_POSEY_2022.0.tif
# Downloaded 49_IN_POSEY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/2b5a6684cbeb8e285da1f8e111af327e-28947b8a2ac022d70aaafe8eaf853388:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/51_IN_VANDERBURGH_2022.0.tif
# Downloaded 51_IN_VANDERBURGH_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/415ddddd0cf850fb4ae1e899a5fe12e2-20bf1dcb3d0e33d13ffa84deba734a8a:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/52_IN_HARRISON_2022.0.tif
# Downloaded 52_IN_HARRISON_2022.0 image patch for corn and soybeans.
# No valid corn or soybean data found for 54_IN_HARRISON_2022.0.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/97b55fb944765246aaab623f86371ba7-6d8a013f0110b22450959c1ab19f1783:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/55_IN_WARRICK_2022.0.tif
# Downloaded 55_IN_WARRICK_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/1ea4ac5fc510fcc616baa176bccfa8de-0a0240cb5f3cc1869bec58ff537a1e3f:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/57_IN_WARRICK_2022.0.tif
# Downloaded 57_IN_WARRICK_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/79b87946ed273bc175ec15e1deeb9749-3a261301f041552b6ff77f91b0b2f954:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/58_IN_PERRY_2022.0.tif
# Downloaded 58_IN_PERRY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/ee9d425d79c56a3308185b0390c1e6da-7a9f8198b5b1b3eeb968e289b5c3fd0a:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/59_IN_WARRICK_2022.0.tif
# Downloaded 59_IN_WARRICK_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/2f75bfb1fe2bb123e9f56149e7a7efa2-9184082191b96126ea3685e4c2882737:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/62_IN_POSEY_2022.0.tif
# Downloaded 62_IN_POSEY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/3e0b7b69cf37387ee711b92f703a7e77-8875fd0d8d5abe946d7ec81b10ca1686:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/63_IN_HARRISON_2022.0.tif
# Downloaded 63_IN_HARRISON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/4037a248aec3564b304e5493a60d5019-28ef99b135038b5c3b44b049894c0de6:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/64_IN_HARRISON_2022.0.tif
# Downloaded 64_IN_HARRISON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/0d100e33f271ae5846ec069b07e699f7-c072deabb63eb61dc515f962db8f76e2:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/65_IN_VANDERBURGH_2022.0.tif
# Downloaded 65_IN_VANDERBURGH_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/c52634e1dc41d013bab9d7188c88482f-1883bf8513858770e5abcdf3e45832fb:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/66_IN_PERRY_2022.0.tif
# Downloaded 66_IN_PERRY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/877f691f65f0c00fd8b8fe0093c1c6a3-a7979f1bd6a52fe685adc74a532e4c44:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/67_IN_HARRISON_2022.0.tif
# Downloaded 67_IN_HARRISON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b6fb7ab265fa068dda2911866e891095-67f2b03c94809db1ced824f8a572c9db:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/68_IN_PERRY_2022.0.tif
# Downloaded 68_IN_PERRY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/c6075dad5fc27088e1c33101cc31ac6f-b07a2c3b9c750a9214f04b9bff03ea97:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/69_IN_POSEY_2022.0.tif
# Downloaded 69_IN_POSEY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/4b9e5884329966f46f3dd348450db9a2-26e45471e333ddd33043011b47af39f4:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/70_IN_VANDERBURGH_2022.0.tif
# Downloaded 70_IN_VANDERBURGH_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/9182c4d5a0e4bc82eeadd09d857c045a-dea6c0ba620b7fe0e7a5b7d9b0bb00fa:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/71_IN_PERRY_2022.0.tif
# Downloaded 71_IN_PERRY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/01f89eb1e9e979a5de29b9ec4753d128-c52db953c8d147300ef1ee24908dd6f8:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/73_IN_HARRISON_2022.0.tif
# Downloaded 73_IN_HARRISON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/58ff0eb3aa69bcf79e47085a9f84d097-0d8325f6396d7d106332f63a047d7118:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/75_IN_PERRY_2022.0.tif
# Downloaded 75_IN_PERRY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b5afc3310c7d5376e4eef7c99b2e7ed4-f7b3a0b3e838dad8af6d009c3432f56f:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/76_IN_VANDERBURGH_2022.0.tif
# Downloaded 76_IN_VANDERBURGH_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/c51ae46f9acd4cd6cd52b2de87d431eb-a802cacc72c625b74930cbb83c1db6c1:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/78_IN_WARRICK_2022.0.tif
# Downloaded 78_IN_WARRICK_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/c25aed291dcdc3d4bd849423dfdb7c98-3ac1ba9cd1cc736d5d15a97f97432572:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/79_IN_VANDERBURGH_2022.0.tif
# Downloaded 79_IN_VANDERBURGH_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/6a509c85ca3282caa98afab6d40c3e90-b6b0513c91b626e60b579f0f3619fa1a:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/80_IN_POSEY_2022.0.tif
# Downloaded 80_IN_POSEY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/a680aa8945704af6eb64c51fd4b184ed-da7ede5f6dad26ae4a9d0836516a1dd1:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/81_IN_WARRICK_2022.0.tif
# Downloaded 81_IN_WARRICK_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/4e2bc83b95b141d2a79f8515fb8fc9a5-5f055f3d5a35a778c1c79bfdda86969a:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/82_IN_PERRY_2022.0.tif
# Downloaded 82_IN_PERRY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/a4090e325eb043649632288a23bdab3d-c74455d35b34f709fd9aac182384bf06:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/84_IN_WARRICK_2022.0.tif
# Downloaded 84_IN_WARRICK_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/9fa2b735fee4df2ecf45f592563da91f-30fc908bb2c0f1ff4bce0af79d390da9:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/86_IN_HARRISON_2022.0.tif
# Downloaded 86_IN_HARRISON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/036b80aa090c4cef1faeed7d78f5758a-a0f53d54665c33f3395fa14c6cb0ba55:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/87_IN_WARRICK_2022.0.tif
# Downloaded 87_IN_WARRICK_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/45cf4a094a0a4d93ebb5283eb9a43955-7a59ffd65d35ec09d5414e805beaffe8:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/88_IN_HARRISON_2022.0.tif
# Downloaded 88_IN_HARRISON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/84d40f7063816b470af8f1051b47f1d8-e930189687824bb6237cee05696ee8b8:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/89_IN_WARRICK_2022.0.tif
# Downloaded 89_IN_WARRICK_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/4f79726cbe92fa0c9340eac06289a9dc-91cd47a1b3a3375f3de57d67b7997a6c:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/90_IN_POSEY_2022.0.tif
# Downloaded 90_IN_POSEY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/f22c9eab3815bb41ab2d46914582cb14-b01da78f5a3037a1240d09ddf24e30b0:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/91_IN_WARRICK_2022.0.tif
# Downloaded 91_IN_WARRICK_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b1b34b9e19885fb70232e32eaa42fbb3-d6a2d4762507a7b9d54308548d148994:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/92_IN_HARRISON_2022.0.tif
# Downloaded 92_IN_HARRISON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/dd7711c15de46a90945e7bff62a1055e-86fdfbf634e1e929ded18fa2ef522275:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/93_IN_POSEY_2022.0.tif
# Downloaded 93_IN_POSEY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/a8dcabd7a9abe128c903bdee5f236972-fa20919023a5a15ff80be63ba86a8d54:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/94_IN_HARRISON_2022.0.tif
# Downloaded 94_IN_HARRISON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/d45685fd7eb87b64d319157f553af43b-22eac329575b2480a16f749166571af0:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/95_IN_PERRY_2022.0.tif
# Downloaded 95_IN_PERRY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/84c9d5f931ffe4daeafa32df93886ae5-d1f87e39767ea49a1e45063160792425:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/96_IN_PERRY_2022.0.tif
# Downloaded 96_IN_PERRY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b0e1a6191159fc8b3b7297d9395dd656-da84c54076dd13c31365e289920ec40b:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/97_IN_POSEY_2022.0.tif
# Downloaded 97_IN_POSEY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/527871ff994cdcb907bf377f9ab4bd09-bc07338a3d3a9981f068d79c1ce950fe:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/98_IN_VANDERBURGH_2022.0.tif
# Downloaded 98_IN_VANDERBURGH_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/ab4aa712dc49da92e282e230c2cbffca-b234440605dda853fb08a76a9bde81d2:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/99_IN_HARRISON_2022.0.tif
# Downloaded 99_IN_HARRISON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/9da748fb1e0d7b95d68ff285c3934f20-3248f019f4b0afdc89f38becfc8f9e30:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/101_IN_VANDERBURGH_2022.0.tif
# Downloaded 101_IN_VANDERBURGH_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/bef4bcd8c8aef99d6a6edf2dd4c850a6-c47ba097f19def7ea00610f85565c06c:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/102_IN_VANDERBURGH_2022.0.tif
# Downloaded 102_IN_VANDERBURGH_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/006c351d782b5e080364c0273ff06170-8f35808b37bcafe1c6cf2d8faff3ad54:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/103_IN_PERRY_2022.0.tif
# Downloaded 103_IN_PERRY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/e86ef9d1067822a8cd937d893b79f1df-b09d8a4d1ab3eb94714a7c94a50ebf53:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/104_IN_PERRY_2022.0.tif
# Downloaded 104_IN_PERRY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/5e375aef084417307261967f842acff6-01f9dc3aff39a77218d648460f989449:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/105_IN_WARRICK_2022.0.tif
# Downloaded 105_IN_WARRICK_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b6911268f5c76890a9f605449bc3f4a6-ff0e02a783ad16ef067e87c8f270484c:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/108_IN_WARRICK_2022.0.tif
# Downloaded 108_IN_WARRICK_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/50b7bdd296270314290361f47ade9747-7bf2628a589da8f7c966a73a510ca2f5:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/109_IN_WARRICK_2022.0.tif
# Downloaded 109_IN_WARRICK_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/ef4b22dc61b5f64baf17c2aafc1c3a18-6fbc364f7c3bd1d07b5b647df74eb456:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/110_IN_PERRY_2022.0.tif
# Downloaded 110_IN_PERRY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/e3cf7197147e84b4c96330e355975d92-044376e12bfbb1c55c088d82925c537c:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/111_IN_VANDERBURGH_2022.0.tif
# Downloaded 111_IN_VANDERBURGH_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/678126e9577216d84e26f0bb1afaea6e-f67523001e9f96e99218442ae1071ec7:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/113_IN_HARRISON_2022.0.tif
# Downloaded 113_IN_HARRISON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/044f9e31c827ff11a13d192b18855bc0-43c22b3fd1f5fb2ae01340b4d312b99c:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/114_IN_POSEY_2022.0.tif
# Downloaded 114_IN_POSEY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/45c2b8bea955046a9429377b4c5ef51d-d4689556d6f49f97dc61f1bc88791fc3:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/115_IN_HARRISON_2022.0.tif
# Downloaded 115_IN_HARRISON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/1b7143427de952f7ec09356658d55ccf-ebe7e40059158ecc6478c2a9d9017f78:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/116_IN_WARRICK_2022.0.tif
# Downloaded 116_IN_WARRICK_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/f264b02b8c5a3281d298e64b8ccd5c41-9b2fd4ce49d44913fa09246dcdc54e5a:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/117_IN_PERRY_2022.0.tif
# Downloaded 117_IN_PERRY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/aea933ab9daf50c42c0a33b38736aff8-2fb55b3a767f4332e117f95b943745f2:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/119_IN_WARRICK_2022.0.tif
# Downloaded 119_IN_WARRICK_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b70fd9b321cba2b8438fbe5c7d533a03-29375f9e6efb285820926df14b0caf49:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/120_IN_WARRICK_2022.0.tif
# Downloaded 120_IN_WARRICK_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/ab82f87ea29942f915fe6e2bae29602d-88ad3a4767647e3d00a3acdc6e1b56ce:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/121_IN_HARRISON_2022.0.tif
# Downloaded 121_IN_HARRISON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/7b84077fbd05bd2f562655432807ce4d-2812e656e50cf67edb94adfea88a1f3c:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/123_IN_HARRISON_2022.0.tif
# Downloaded 123_IN_HARRISON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/1abef5916ee3990c0200bba8a999adda-ca946f4873e587e61355780d888b9a0a:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/124_IN_POSEY_2022.0.tif
# Downloaded 124_IN_POSEY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/d96e26d2253215c81d12b1ac2a8f82d8-b96e12ad04df9800bf4a946929bd6d0c:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/126_IN_WARRICK_2022.0.tif
# Downloaded 126_IN_WARRICK_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/6e89d602e725582cbffdc63315d647c7-405e89afc7f83fa0a9c706b3716cb231:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/127_IN_GIBSON_2022.0.tif
# Downloaded 127_IN_GIBSON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/c5af65253377ad9f5e61b2cdd17fb05f-a5ab3eb6a9fe9b31e01f4417046e425a:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/129_IN_POSEY_2022.0.tif
# Downloaded 129_IN_POSEY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/40ed4db45038ce7095a2861a4f708ea5-b1b677458ed5ba5a995d4a792b2b2418:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/130_IN_HARRISON_2022.0.tif
# Downloaded 130_IN_HARRISON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/f3d9eb88acb9ba8c8f7d2fa812b0803c-8c43ec7c85468df6822d0d906a4f80f7:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/131_IN_WARRICK_2022.0.tif
# Downloaded 131_IN_WARRICK_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/c6d89fdfff4e587a9396a537f52f0b03-8440de683ca6c477096cb49a428a2553:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/132_IN_GIBSON_2022.0.tif
# Downloaded 132_IN_GIBSON_2022.0 image patch for corn and soybeans.
# No valid corn or soybean data found for 133_IN_PERRY_2022.0.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/fb269f37bbd0990fad45818942192bfd-0edbadd76ae85cc880cd1b62d31b75cd:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/134_IN_GIBSON_2022.0.tif
# Downloaded 134_IN_GIBSON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/afda530f5cb7a9ff671978941300e3d5-a0d84037f92131301b02b2ce3f3c9db5:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/135_IN_PERRY_2022.0.tif
# Downloaded 135_IN_PERRY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/c0eecebf7972a6d5c5592906356e0e53-6eafec213b6d04fa1b7f59942473b3a4:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/137_IN_DUBOIS_2022.0.tif
# Downloaded 137_IN_DUBOIS_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/d281e2bce021c96f7cae7abaf41f79ff-c422f201996c3a55a6508a071e02b520:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/138_IN_PERRY_2022.0.tif
# Downloaded 138_IN_PERRY_2022.0 image patch for corn and soybeans.
# No valid corn or soybean data found for 139_IN_HARRISON_2022.0.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/8a00944755db15f2fbcfc084a047c8b9-a2f66449fdd82b51a25ae723c6f2bbf6:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/140_IN_WARRICK_2022.0.tif
# Downloaded 140_IN_WARRICK_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/3104285e823380fb06ada06e7fa7e283-1458bbc3ba633f8d3892fe34ab98b303:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/141_IN_HARRISON_2022.0.tif
# Downloaded 141_IN_HARRISON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/8cc104cf8d577806bb343bdf652751ba-aa427a6804e4e80c3aa9241a4cf100a4:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/142_IN_WARRICK_2022.0.tif
# Downloaded 142_IN_WARRICK_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/c40970459636a25eccb21a702d319114-0b359fec7de5a081d520d4fed440433e:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/143_IN_PERRY_2022.0.tif
# Downloaded 143_IN_PERRY_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/a0165186b528e992a1c7d3811c3d7479-b04cbc8da540a5f4d11a2136418220c5:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/146_IN_GIBSON_2022.0.tif
# Downloaded 146_IN_GIBSON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/3942b2f72acb7394e308c5021345c284-6566d2a4512aacd03305485a7a7031d8:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/147_IN_DUBOIS_2022.0.tif
# Downloaded 147_IN_DUBOIS_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/8b99235073143d37904bce2d1be849de-4f4826e5560f5836a8d01121c39a36ee:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/148_IN_HARRISON_2022.0.tif
# Downloaded 148_IN_HARRISON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/9dbd04a7a3467e44b90e3f1ef328c0eb-2a33d4599853f046ae2407a36be3eb75:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/149_IN_DUBOIS_2022.0.tif
# Downloaded 149_IN_DUBOIS_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/47a2ff1c19ea292e4d6caf7893978679-bbf4a3852d9c8187c4eba041436944c7:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/150_IN_GIBSON_2022.0.tif
# Downloaded 150_IN_GIBSON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/635ff70e5ccedb105521d7d18b9abf47-40c4bc40bd18f9d5ab09019bc9206a99:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/152_IN_GIBSON_2022.0.tif
# Downloaded 152_IN_GIBSON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/188780485286f5f53553ce9d27cb4b29-afcdc5aa0ac9580bebf481060d6d0b50:getPixels
# Please wait ...
# ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/1248_IN_RANDOLPH_2022.0.tif
# Downloaded 1248_IN_RANDOLPH_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/4aa11164ea29178dadee42ce332f8edd-a70fa4e108aba8e7188a116f7e93198c:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/1249_IN_RANDOLPH_2022.0.tif
# Downloaded 1249_IN_RANDOLPH_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/4cc9a9e7d92d021fa64f5b13904fa684-eb669008d0daa1b17021f4f3d88079a6:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/1250_IN_BOONE_2022.0.tif
# Downloaded 1250_IN_BOONE_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/4f57b964c3c63965fa36578f83e6d2e1-99de0be1c7ee6d3d744627cb32dadbf9:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/1251_IN_DELAWARE_2022.0.tif
# Downloaded 1251_IN_DELAWARE_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/d36cd6db7a0154c544bcb91ffe281c15-1ab83178ec428cbc05733f7f621f224c:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/1253_IN_MADISON_2022.0.tif
# Downloaded 1253_IN_MADISON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/4744d1aa84096c0863b1a82df41959f5-f4ea7607d7c075258ab65807f21a3f23:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/1255_IN_MADISON_2022.0.tif
# Downloaded 1255_IN_MADISON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/3cc1af73451f8cc820bc34eed356925d-9967581957984845d18e6d6d17dcc7c4:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/1256_IN_HAMILTON_2022.0.tif
# Downloaded 1256_IN_HAMILTON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/6afd196b8003fa0cefd5439b7eb2071f-9183fccc2e9ecc4f4ca8cb6ba58f4be4:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/1257_IN_MADISON_2022.0.tif
# Downloaded 1257_IN_MADISON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/8dcd2d496eff5cb2634178332d5cce0a-13e80769a68afdc5d0496393db099e9d:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/1258_IN_BOONE_2022.0.tif
# Downloaded 1258_IN_BOONE_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/c9dfbd39c65c4d227c7eccfdd68e5f7d-4eee03ce731961371faddfa77e53854c:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/1260_IN_DELAWARE_2022.0.tif
# Downloaded 1260_IN_DELAWARE_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/3f2de6d2cc9f0cbd5a7480d8d1ed5fd2-501f2784326e0cc03b55c508aa169605:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/1261_IN_BOONE_2022.0.tif
# Downloaded 1261_IN_BOONE_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/372489f7d921bea743246742287be632-ea85df53a97857dba102cdd5b8df5470:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/1262_IN_DELAWARE_2022.0.tif
# Downloaded 1262_IN_DELAWARE_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/11aa52471aa1f37b3302c8310be86ed5-1272fb1ecd8251fec2b3643095116047:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/1265_IN_RANDOLPH_2022.0.tif
# Downloaded 1265_IN_RANDOLPH_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/4537c551be317cbe32db65b08bc112c8-233e3719837d8b354851b8dec47b1efa:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/1266_IN_MADISON_2022.0.tif
# Downloaded 1266_IN_MADISON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/abde72cdeba494f804ace0950f4a0e93-c916b234efe32897f56de3f8a4d7d1de:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/1267_IN_DELAWARE_2022.0.tif
# Downloaded 1267_IN_DELAWARE_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/4f2b1f3d08762e58d0e8fc30cd5081fa-b55714ba830219de6946372b0aac80f2:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/1269_IN_CLINTON_2022.0.tif
# Downloaded 1269_IN_CLINTON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/5f87d275d80d190403faea22ef5cf6a7-a7d6a1941ff8257af5d83e7959dd6e63:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/1270_IN_DELAWARE_2022.0.tif
# Downloaded 1270_IN_DELAWARE_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/83139ce2286f5d4257e45bc5789c6f26-4dba386303cd59bd3ada3da27b1a5958:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/1271_IN_RANDOLPH_2022.0.tif
# Downloaded 1271_IN_RANDOLPH_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/1d1093b40a9eea965ce979853b7f982a-f03dc784c4478fa3b51bd2a35a01038b:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/1272_IN_CLINTON_2022.0.tif
# Downloaded 1272_IN_CLINTON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/a6bb34b4ea63cd50a5b5fc3be3650536-854829981418c6a92d90fad3c71c9063:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/1276_IN_HAMILTON_2022.0.tif
# Downloaded 1276_IN_HAMILTON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/c9b440192383138322fa626708491ed2-8b33d2cb660b4b058d56925403d14163:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/1277_IN_HAMILTON_2022.0.tif
# Downloaded 1277_IN_HAMILTON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/6adf11f94972828a500f3c552fd255a8-4aedb2399ac2f7df79f4b54b3b82d8a4:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/1278_IN_HAMILTON_2022.0.tif
# Downloaded 1278_IN_HAMILTON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/d66fa72753168580302167cc04abd4e7-b66cece3f4271f79b0744bf4a16b952d:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/1279_IN_CLINTON_2022.0.tif
# Downloaded 1279_IN_CLINTON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b79ac17705a0905af8877634e1a98557-3f6363eac128b51c024406f5b8864a68:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/1280_IN_HAMILTON_2022.0.tif
# Downloaded 1280_IN_HAMILTON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/11ece5698283b601fba73e7f51006df5-edf0da3f2fc7958ef7432fa36bbb48cc:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/1281_IN_CLINTON_2022.0.tif
# Downloaded 1281_IN_CLINTON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/75414239ab8aa875912200d2dca91bb9-0b186a5edb502500061bc96b7ff2cac0:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/1282_IN_MADISON_2022.0.tif
# Downloaded 1282_IN_MADISON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/f3cd9d6927fc1b1a5ef37a18332e6827-edafc13ae3dcfda4ef93cd3293b37454:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/1283_IN_CLINTON_2022.0.tif
# Downloaded 1283_IN_CLINTON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/d662ea910bd1bee84681cefadbfb2a3b-354bd9286dddfd1ae77c4af384324eb3:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/1284_IN_TIPPECANOE_2022.0.tif
# Downloaded 1284_IN_TIPPECANOE_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/01b6bd814d8a5a84800dd7c86534cf93-2bc0c4e1399fe048d6f9bbca69f44161:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/1285_IN_RANDOLPH_2022.0.tif
# Downloaded 1285_IN_RANDOLPH_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/6c53153272ba4662118012cc9993d662-f35f482efdb15066b324d37f50fa049b:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/1286_IN_TIPPECANOE_2022.0.tif
# Downloaded 1286_IN_TIPPECANOE_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b00a31808cc9823d65d2b5f3dc6e0e8c-93dc7d7a07927f85e0048977192433dd:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/1287_IN_RANDOLPH_2022.0.tif
# Downloaded 1287_IN_RANDOLPH_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/3e1eef8f48490b7d1694da54d181fec5-74b99ca1b80e48ce2b841f3d1129167b:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/1288_IN_TIPPECANOE_2022.0.tif
# Downloaded 1288_IN_TIPPECANOE_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/d065d641c6be09e047b5465b9d565fba-4ef0921f422c6d9c6bc0a4695cd96fe8:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/1289_IN_RANDOLPH_2022.0.tif
# Downloaded 1289_IN_RANDOLPH_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b8fc5a3d6920d04bc73d8e43719e71dd-c144a574bd8ff62a3a7115f548690704:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/1290_IN_DELAWARE_2022.0.tif
# Downloaded 1290_IN_DELAWARE_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/1986208c4f84703aa514a9cc79e366ab-62c84fa9b528b944ac7ec3e7f9daed37:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/1291_IN_CLINTON_2022.0.tif
# Downloaded 1291_IN_CLINTON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/016b71920b4a3c87e4355c5ac4823a72-c70d8baad0e85af703d2e483bbb77d54:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/1292_IN_DELAWARE_2022.0.tif
# Downloaded 1292_IN_DELAWARE_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/682357bff5a8579839e7474f46329be0-0a9806e2107f718bef4613754707f997:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/Thesis/Models_training/Full_Data/output_corrected/INDIANA/Indiana_32615/2022/CDL_images/1295_IN_MADISON_2022.0.tif
# Downloaded 1295_IN_MADISON_2022.0 image patch for corn and soybeans.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/041feb81185f957179fdaaa9f8296e6b-abe0d3bbf60ed6b194a463943fcbf7e6:getPixels
# Please wait ...
